# %% [markdown]
# ###  Python is General purpose high level programming language

# %% [markdown]
# 1. General purpose means use anywhere  artificial intelligence, mobile applications, desktop applications, NASA

# %%
a= 10
b= 20
print (a if a>b else b)
# Out:
# 20

# %% [markdown]
# - if a pod depoly trow the resource
# - does not matter to put to a place

# %% [markdown]
# ```yaml
# apiVersion: v1
# kind: Pod
# metadata:
#   name: frontend
# spec:
#   containers:
#   - name: app
#     image: images.my-company.example/app:v4
#     resources:
#       requests:
#         memory: "64Mi"
#         cpu: "250m"
#       limits:
#         memory: "128Mi"
#         cpu: "500m"
# ```
